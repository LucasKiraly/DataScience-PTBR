# %% [markdown]
# # Naive Bayes - Iris
# Este projeto tem como objetivo demonstrar de forma simplificada o uso do modelo Naive Bayes para classificação das espécies da flor íris.
#
# O conjunto de dados utilizado para este projeto foi o ["Iris Species"](https://www.kaggle.com/uciml/iris) retirado diretamente da plataforma Kaggle.

# %% [markdown]
# # Bibliotecas utilizadas

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Dados

# %%
# Importando os dados
dados = pd.read_csv('Iris.csv')

# Exibindo as 5 primeiras entradas do nosso conjunto de dados
dados.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Verificando a descrição dos dados
dados.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Visualizando e analisando os dados - Sépala

# %% [markdown]
# ### Comprimento

# %%
# Criando box plot referente ao comprimento da sépala
fig_comprimento_sepala = px.box(dados, x='Species', y='SepalLengthCm', color='Species')

# Inserindo títulos aos eixos do gráfico
fig_comprimento_sepala.update_layout(xaxis_title='Espécies', yaxis_title='Comprimento da sépala')

# Exbibindo o box plot
fig_comprimento_sepala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - A espécie Iris-setosa apresenta uma menor comprimento de sépala quando comparada as outras espécies;
# - A dispersão dos dados referentes a esta mesma espécie também é menor quando comparada as outras, indicando uma menor variabilidade em seu comprimento.

# %% [markdown]
# ### Largura

# %%
# Criando o box plot referente a largura da sépala
fig_largura_sepala = px.box(dados, x='Species', y='SepalWidthCm', color='Species')

# Inserindo títulos aos eixos do gráfico
fig_largura_sepala.update_layout(xaxis_title='Espécies', yaxis_title='Largura da sépala')

# Exibindo o box plot
fig_largura_sepala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - A espécie Iris-setosa possui uma largura de sépala consideravelmente maior do que as outras espécies;
# - Enquanto a espécie Iris-virginica é a que apresenta menor variabilidade quando análisamos a largura da sépala.

# %% [markdown]
# ### Comprimento x Largura

# %%
# Criando gráfico de pontos - Comprimento x Largura
fig_caracteristicas_sepala = px.scatter(dados, x="SepalLengthCm", y="SepalWidthCm", color="Species")

# Inserindo títulos aos eixos do gráfico
fig_caracteristicas_sepala.update_layout(xaxis_title='Comprimento da sépala', yaxis_title='Largura da sépala')

# Exibindo o gráfico de pontos
fig_caracteristicas_sepala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - Ao analisarmos o gráfico de pontos notamos que as características da sépala podem ser um bom classificador para a espécie Iris-setosa, entretanto para as espécies Versicolor e Virginica devido suas carcterísticas razoavelmente semelhantes pode gerar certa dificuldade ao classificador.

# %% [markdown]
# # Visualizando e analisando os dados - Pétala

# %% [markdown]
# ### Comprimento

# %%
# Criando box plot referente ao comprimento da pétala
fig_comprimento_petala = px.box(dados, x='Species', y='PetalLengthCm', color='Species')

# Inserindo títulos aos eixos do gráfico
fig_comprimento_petala.update_layout(xaxis_title='Espécies', yaxis_title='Comprimento da pétala')

# Exbibindo o box plot
fig_comprimento_petala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - Diferentemente das características analisadas anteriormente, o comprimento da pétala, aponta uma notável distinção entre as espécies, sendo:
#  - Iris-setosa a de menor comprimento;
#  - Iris-versicolor de comprimento intermediário;
#  - Iris-virginica de maior comprimento.

# %% [markdown]
# ### Largura

# %%
# Criando box plot referente a largura da pétala
fig_largura_petala = px.box(dados, x='Species', y='PetalWidthCm', color='Species')

# Inserindo títulos aos eixos do gráfico
fig_largura_petala.update_layout(xaxis_title='Espécies', yaxis_title='Largura da pétala')

# Exbibindo o box plot
fig_largura_petala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - De maneira semelhante ao comprimento, a largura de pétala também é capaz de indicar uma distinção entre as espécies, sendo:
#  - Iris-setosa a de menor largura;
#  - Iris-versicolor de largura intermediário;
#  - Iris-virginica de maior largura.

# %% [markdown]
# ### Comprimento x Largura

# %%
# Criando gráfico de pontos - Comprimento x Largura
fig_caracteristicas_petala = px.scatter(dados, x="PetalLengthCm", y="PetalWidthCm", color="Species")

# Inserindo títulos aos eixos do gráfico
fig_caracteristicas_petala.update_layout(xaxis_title='Comprimento da pétala', yaxis_title='Largura da pétala')

# Exibindo o gráfico de pontos
fig_caracteristicas_petala.show('png', width=1000, height=500)

# %% [markdown]
# Observações:
# - Diferentemente das características de sépala, quando comparamos os atributos da pétala em um gráfico de pontos, notamos a existência de um melhor classificador entre as espécies.

# %% [markdown]
# # Visualizando e analisando os dados - Mediana

# %%
# Criando um DataFrame com a mediana de todas as características por espécie
data_frame_caracteristicas = dados.groupby(['Species'], as_index=False)[['SepalLengthCm', 'SepalWidthCm', 
                                                                         'PetalLengthCm', 'PetalWidthCm']].median()

# Exbindo o novo DataFrame criado
data_frame_caracteristicas
# Out:
#            Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      Iris-setosa            5.0           3.4           1.50           0.2
# 1  Iris-versicolor            5.9           2.8           4.35           1.3
# 2   Iris-virginica            6.5           3.0           5.55           2.0

# %% [markdown]
# Observações:
# - A criação deste DataFrame tem como obejtivo demonstrar através da mediana a confirmação das observações realizadas anteriormente através dos gráficos apresentados;
# - Optamos pelo uso da mediana ao invés da média pois esta estimativa é resistente a possíveis outliers existentes em nossos dados.

# %% [markdown]
# # Modelo - Naive Bayes

# %% [markdown]
# ### Variáveis

# %%
# Definindo as características
X = dados.drop(["Species", 'Id'], axis=1)

# Definindo os rótulos
y = dados['Species']

# %% [markdown]
# ### Treino e teste

# %%
# Separando os dados em treino e teste 
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3) # 30% dos dados serão para teste

# %% [markdown]
# ### Modelo

# %%
# Criando o modelo Naive Bayes
modelo_nb = GaussianNB()

# Treinando o modelo
modelo_nb.fit(X_treino, y_treino)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ### Predição

# %%
# Realizando predições
predicao = modelo_nb.predict(X_teste)

# %% [markdown]
# ### Resultados - Precisão do modelo

# %%
# Porcentagem de acertos
precisao = accuracy_score(y_teste, predicao)

# Exibindo precisão do modelo - Porcentagem de acertos
print("Precisão do modelo: %.2f%%" %(precisao*100))
# Out:
# Precisão do modelo: 93.33%

# %%
# Número de acertos
num_acertos = accuracy_score(y_teste, predicao, normalize=False)

# Exibindo número de previsões
print("Número de previsões:", predicao.size)

# Exibindo precisão do modelo - Número de acertos
print("Número de acertos do modelo:", num_acertos)
# Out:
# Número de previsões: 45
# Número de acertos do modelo: 42

# %% [markdown]
# ### Resultados - Comparando valores reais com as predições

# %%
# Criando um DataFrame para exibir a comparação
df_comparacao = X_teste

# Criando coluna no DataFrame para os rótulos reais
df_comparacao['Rótulo real'] = y_teste

# Criando coluna no DataFrame para os rótulos preditos
df_comparacao['Rótulo predito'] = predicao.tolist()

# Exibindo os 10 primeiras entradas do nosso novo conjunto
df_comparacao.head(10)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 114            5.8           2.8            5.1           2.4
# 38             4.4           3.0            1.3           0.2
# 28             5.2           3.4            1.4           0.2
# 145            6.7           3.0            5.2           2.3
# 136            6.3           3.4            5.6           2.4
# 72             6.3           2.5            4.9           1.5
# 56             6.3           3.3            4.7           1.6
# 144            6.7           3.3            5.7           2.5
# 25             5.0           3.0            1.6           0.2
# 85             6.0           3.4            4.5           1.6
#
#          Rótulo real   Rótulo predito
# 114   Iris-virginica   Iris-virginica
# 38       Iris-setosa      Iris-setosa
# 28       Iris-setosa      Iris-setosa
# 145   Iris-virginica   Iris-virginica
# 136   Iris-virginica   Iris-virginica
# 72   Iris-versicolor  Iris-versicolor
# ...
